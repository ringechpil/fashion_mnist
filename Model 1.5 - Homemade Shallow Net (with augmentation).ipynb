# %% [markdown]
# # CNN for Fashion-MNIST dataset
#
# ### Problem Description
#
# We're provided with a dataset of small grayscale images depicting various clothing objects. They are subdivided into ten classes, and our goal is to build a CNN that predicts those classes as precisely as possible. We will build several (simple) CNNs and then compare their performace and efficiency.

# %% [markdown]
# ### Loading and preparing the dataset

# %%
import warnings
warnings.filterwarnings("ignore")

from random import randrange
import numpy as np
import matplotlib.pyplot as plt

# %%
#loading the train and the test set
from keras.datasets import fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
print(X_train.shape, X_test.shape)
# Out:
# Using TensorFlow backend.
# (60000, 28, 28) (10000, 28, 28)

# %%
#labeling the classes and displaying some images from the dataset
class_labels = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']


plt.figure(figsize=(8,8))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    #plt.grid(False)
    k = randrange(6000)
    plt.imshow(X_train[k], cmap=plt.cm.binary)
    plt.xlabel(class_labels[y_train[k]])
plt.show()

# %% [markdown]
# The train and the test sets are given as a three-dimensional vectors. However, in order to feed our CNN with the images, we need them to be 4D vectors. That's why wee need to add an additional dimension. This additional dimension tells the number of channels. Since our images are in grayscale, we have only one channel.
#
# Also, we scale the values of every entry, and one-hot encode the classes.

# %%
#Adding the fourth axis
X_train = np.expand_dims(X_train, axis = 3)
X_test = np.expand_dims(X_test, axis = 3)

# %%
#Scaling the values to [0,1] range
X_train = X_train.astype('float')
X_test = X_test.astype('float')

X_train = X_train/255
X_test = X_test/255

# %%
#Encoding the classes
from keras.utils import to_categorical

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# ### Building the CNN
#
# Here we build a pretty simple CNN, consisting of two convolutional layers equipped with max-pool layer each, and two fully-connected layers. We use 3x3 kernels, add padding, use small regularization and the dropout. ReLu and softmax (in the last layer) are used as activation functions. We use the categorical crossentropy for the loss function, and nadam optimizer.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dropout, Dense, Flatten
from keras.optimizers import nadam
from keras.regularizers import l2

# %%
cnn = Sequential()

cnn.add(Conv2D(input_shape = (28, 28, 1), filters = 32, 
              kernel_size = (3,3), activation = 'relu', 
              padding='same', kernel_regularizer=l2(5e-5)))
cnn.add(MaxPool2D((2,2)))


cnn.add(Conv2D(filters = 32, 
              kernel_size = (3,3), activation = 'relu', 
              padding='same', kernel_regularizer=l2(5e-5)))
cnn.add(MaxPool2D((2,2)))


cnn.add(Flatten())


cnn.add(Dense(units = 256, activation='relu', 
              kernel_regularizer=l2(5e-5)))
cnn.add(Dropout(0.15))
cnn.add(Dense(units = 10, activation = 'softmax'))

# %%
cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1568)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               401664
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 413,802
# Trainable params: 413,802
# Non-trainable params: 0
# _________________________________________________________________

# %%
cnn.compile(loss = 'categorical_crossentropy', 
           optimizer = nadam(lr = 0.001),
           metrics = ['accuracy'])

# %% [markdown]
# ### Augmenting the data
#
# Here we train our CNN on the augmented dataset. Since the images are small, we apply just few minor transformations.
#
# We perform the training in 45 epochs, which takes approximately 45 minutes, because 1 epoch takes about a minute to finish.
#
# (Since I have an integrated Intel graphic card, I had to the train the network using CPU; running it on GPU would allow me to train it significantly faster, for more epochs, which could lead to  better accuracy)

# %%
from keras.preprocessing.image import ImageDataGenerator

imgen = ImageDataGenerator(rotation_range=5,
        zoom_range = 0.01,
        width_shift_range=0.03,  
        height_shift_range=0.03)

imgen.fit(X_train)

# %%
history = cnn.fit_generator(imgen.flow(X_train, y_train, batch_size = 64), 
                            epochs = 45, 
                            validation_data= (X_test, y_test), 
                            verbose=1)
# Out:
# Epoch 1/45
# 938/938 [==============================] - 67s 72ms/step - loss: 0.5199 - accuracy: 0.8186 - val_loss: 0.3654 - val_accuracy: 0.8756
# Epoch 2/45
# 938/938 [==============================] - 63s 67ms/step - loss: 0.3643 - accuracy: 0.8773 - val_loss: 0.3414 - val_accuracy: 0.8860
# Epoch 3/45
# 938/938 [==============================] - 59s 63ms/step - loss: 0.3306 - accuracy: 0.8899 - val_loss: 0.3211 - val_accuracy: 0.8975
# Epoch 4/45
# 938/938 [==============================] - 58s 62ms/step - loss: 0.3102 - accuracy: 0.8982 - val_loss: 0.3179 - val_accuracy: 0.9014
# Epoch 5/45
# 938/938 [==============================] - 58s 62ms/step - loss: 0.2946 - accuracy: 0.9067 - val_loss: 0.2990 - val_accuracy: 0.9026
# Epoch 6/45
# 938/938 [==============================] - 58s 62ms/step - loss: 0.2859 - accuracy: 0.9104 - val_loss: 0.2806 - val_accuracy: 0.9117
# Epoch 7/45
# 938/938 [==============================] - 62s 66ms/step - loss: 0.2750 - accuracy: 0.9136 - val_loss: 0.3030 - val_accuracy: 0.9085
# Epoch 8/45
# 938/938 [==============================] - 60s 64ms/step - loss: 0.2671 - accuracy: 0.9172 - val_loss: 0.2732 - val_accuracy: 0.9163
# Epoch 9/45
# 938/938 [==============================] - 61s 65ms/step - loss: 0.2638 - accuracy: 0.9199 - val_loss: 0.2849 - val_accuracy: 0.9109
# Epoch 10/45
# 938/938 [==============================] - 61s 65ms/step - loss: 0.2568 - accuracy: 0.9217 - val_loss: 0.2698 - val_accuracy: 0.9205
# Epoch 11/45
# 938/938 [==============================] - 59s 63ms/step - loss: 0.2519 - accuracy: 0.9249 - val_loss: 0.2806 - val_accuracy: 0.9209
# Epoch 12/45
# 938/938 [==============================] - 58s 62ms/step - loss: 0.2480 - accuracy: 0.9274 - val_loss: 0.2711 - val_accuracy: 0.9204
# Epoch 13/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2459 - accuracy: 0.9281 - val_loss: 0.2823 - val_accuracy: 0.9170
# Epoch 14/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2407 - accuracy: 0.9305 - val_loss: 0.2798 - val_accuracy: 0.9211
# Epoch 15/45
# 938/938 [==============================] - 58s 62ms/step - loss: 0.2398 - accuracy: 0.9305 - val_loss: 0.2901 - val_accuracy: 0.9168
# Epoch 16/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2386 - accuracy: 0.9307 - val_loss: 0.2892 - val_accuracy: 0.9176
# Epoch 17/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2333 - accuracy: 0.9341 - val_loss: 0.2740 - val_accuracy: 0.9236
# Epoch 18/45
# 938/938 [==============================] - 58s 62ms/step - loss: 0.2331 - accuracy: 0.9334 - val_loss: 0.2777 - val_accuracy: 0.9246
# Epoch 19/45
# 938/938 [==============================] - 60s 64ms/step - loss: 0.2328 - accuracy: 0.9347 - val_loss: 0.3007 - val_accuracy: 0.9188
# Epoch 20/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2284 - accuracy: 0.9352 - val_loss: 0.2880 - val_accuracy: 0.9226
# Epoch 21/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2279 - accuracy: 0.9364 - val_loss: 0.2777 - val_accuracy: 0.9250
# Epoch 22/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2251 - accuracy: 0.9369 - val_loss: 0.2763 - val_accuracy: 0.9255
# Epoch 23/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2253 - accuracy: 0.9365 - val_loss: 0.2801 - val_accuracy: 0.9266
# Epoch 24/45
# 938/938 [==============================] - 58s 62ms/step - loss: 0.2208 - accuracy: 0.9403 - val_loss: 0.2862 - val_accuracy: 0.9249
# Epoch 25/45
# 938/938 [==============================] - 58s 61ms/step - loss: 0.2215 - accuracy: 0.9393 - val_loss: 0.2856 - val_accuracy: 0.9268
# Epoch 26/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2189 - accuracy: 0.9405 - val_loss: 0.3032 - val_accuracy: 0.9186
# Epoch 27/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2187 - accuracy: 0.9414 - val_loss: 0.2968 - val_accuracy: 0.9222
# Epoch 28/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2185 - accuracy: 0.9410 - val_loss: 0.2853 - val_accuracy: 0.9237
# Epoch 29/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2143 - accuracy: 0.9427 - val_loss: 0.2836 - val_accuracy: 0.9282
# Epoch 30/45
# 938/938 [==============================] - 58s 61ms/step - loss: 0.2154 - accuracy: 0.9423 - val_loss: 0.2882 - val_accuracy: 0.9241
# Epoch 31/45
# 938/938 [==============================] - 59s 63ms/step - loss: 0.2152 - accuracy: 0.9427 - val_loss: 0.2832 - val_accuracy: 0.9244
# Epoch 32/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2120 - accuracy: 0.9436 - val_loss: 0.2875 - val_accuracy: 0.9281
# Epoch 33/45
# 938/938 [==============================] - 58s 62ms/step - loss: 0.2149 - accuracy: 0.9428 - val_loss: 0.2780 - val_accuracy: 0.9266
# Epoch 34/45
# 938/938 [==============================] - 58s 61ms/step - loss: 0.2115 - accuracy: 0.9443 - val_loss: 0.2958 - val_accuracy: 0.9249
# Epoch 35/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2109 - accuracy: 0.9450 - val_loss: 0.2933 - val_accuracy: 0.9242
# Epoch 36/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2074 - accuracy: 0.9468 - val_loss: 0.2953 - val_accuracy: 0.9260
# Epoch 37/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2110 - accuracy: 0.9447 - val_loss: 0.2967 - val_accuracy: 0.9253
# Epoch 38/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2085 - accuracy: 0.9467 - val_loss: 0.3010 - val_accuracy: 0.9244
# Epoch 39/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2055 - accuracy: 0.9469 - val_loss: 0.2997 - val_accuracy: 0.9259
# Epoch 40/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2087 - accuracy: 0.9467 - val_loss: 0.2919 - val_accuracy: 0.9244
# Epoch 41/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2057 - accuracy: 0.9484 - val_loss: 0.2865 - val_accuracy: 0.9270
# Epoch 42/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2035 - accuracy: 0.9483 - val_loss: 0.2993 - val_accuracy: 0.9244
# Epoch 43/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2041 - accuracy: 0.9483 - val_loss: 0.3056 - val_accuracy: 0.9267
# Epoch 44/45
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2059 - accuracy: 0.9483 - val_loss: 0.2917 - val_accuracy: 0.9249
# Epoch 45/45
# 938/938 [==============================] - 57s 60ms/step - loss: 0.2047 - accuracy: 0.9488 - val_loss: 0.2975 - val_accuracy: 0.9258

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xticks(np.arange(0,46,5))
plt.ylim(0.75,1), plt.yticks(np.arange(0.75,1.025,0.025))
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ### Accuracy Analysis
#
# At the end of the training, our model classified the images with the 94.9% accuracy on the last iteration of the augmented training set, and 92.6% on the test set. If we focus on the test set performance, we can gain the similar accuracy even after ~10 minutes of training (on CPU), since the model achieves it after 10 epochs.
#
# Let's now draw the confusion matrix for our model, and see how it performs on several randomly chosen images.

# %%
from sklearn.metrics import confusion_matrix

y_pred = cnn.predict_classes(X_test)
y_test_class = y_test.argmax(1)

cm = confusion_matrix(y_test_class, y_pred)

# %%
import itertools

# Function to plot a confusion matrix
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Reds):

    # Plot the confusion matrix as an image
    plt.figure(figsize = (14, 14))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, size = 22)
    
    # Tick marks show the labels
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    # Add the numbers to the plot
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], 'd'),
                 horizontalalignment="center", size = 18,
                 color="white" if cm[i, j] > thresh else "black")

    # Formatting
    plt.tight_layout()
    plt.xticks(size = 18)
    plt.yticks(size = 18)
    plt.ylabel('True label', size = 18)
    plt.xlabel('\n Predicted label', size = 18)

# %%
plot_confusion_matrix(cm, class_labels)

# %%
X_test_sq = np.squeeze(X_test, axis = 3)
plt.figure(figsize=(14,14))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    #plt.grid(False)
    k = randrange(6000)
    plt.imshow(X_test_sq[k], cmap=plt.cm.binary)
    plt.xlabel('True class: ' + class_labels[y_test_class[k]] +
        '\n Predicted class: ' + class_labels[y_pred[k]])
plt.show()

# %% [markdown]
# ### Conclusions
#
# We see that our model has a bit of a trouble distinguishing among T-shirt/shirts/coat classes and sneaker/boot classes. However, it still performs fine on a test set, its architecture is quite simple and can be trained relatively fast.
